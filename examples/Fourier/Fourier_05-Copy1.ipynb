# %% [markdown]
# You can save your work offline (without risk of loss of data) by using `File->Download`. Later you can upload your creationg back to the online environment using the "upload" button ![image.png](attachment:9af029fd-4903-4ebf-87d6-5c31c2365f07.png)

# %% [markdown]
# ## Setup

# %%
# SETUP CELL
# %pip -q install numpy sympy matplotlib ipywidgets pandas plotly anywidget scipy
import src_path
from gu_toolkit import *
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
base_freq=220
df=0
play(sin(2*pi * base_freq*exp(log(2**(1/12.0))*df)*x),(x,0,10))
# Out:
# <audio controls src="data:audio/wav;base64,..."></audio>

# %%
expr1=0
expr2=0
expr3=0
base_freq=220
for k in np.arange(-11,11+0.1,):
    #print(k)
    expr1=expr1+exp(-10*abs(k+x/10-floor(x/10) ))*sin(2*pi * base_freq*exp(log(2)*(k+x/10 -floor(x/10)))*x)
    expr2=expr2+exp(-10*abs(k))*sin(2*pi * base_freq*exp(log(2)*(k))*x)
    expr3=expr3+exp(-10*abs(k+10/10))*sin(2*pi * base_freq*exp(log(2)*(k+10/10))*x)
display(expr1)
display(expr2)
display(expr3)

# %%
display(play(expr1,(x,0,30)))
display(play(expr2,(x,0,30)))
display(play(expr2,(x,0,30)))

# %%
expr1-expr2

# %%
floor(1)

# %%
fig=Figure()
fig.show()

# %%
with fig:
    set_x_range((-0.1,0.1))
    set_y_range((-2,2))
    plot(expr1,(x,0,0.01),id="expr1", sampling_points =1000)

# %%
fig.plot?

# %%
play(sin(2*pi * base_freq*x**2),(x,0,10))
# Out:
# <audio controls src="data:audio/wav;base64,..."></audio>

# %% [markdown]
# You can save your work offline (without risk of loss of data) by using `File->Download`. Later you can upload your creationg back to the online environment using the "upload" button ![image.png](attachment:9af029fd-4903-4ebf-87d6-5c31c2365f07.png)

# %% [markdown]
# ## Setup

# %%
# SETUP CELL

# %pip -q install numpy sympy matplotlib ipywidgets pandas plotly anywidget scipy
import src_path
from gu_toolkit import *
from helpers.Fourier_01_helper import *
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Finding a mystery function as a sum of sines

# %% [markdown]
# Our mystery function looks like this
#
# $$
# F(x)= α_1\,\sin(2\pi 1 x)+α_2\,\sin(2\pi 2 x) + \ldots +α_{N} \,\sin(2\pi N x)
# $$
#
# The numbers $α_n$ will be chosen randomly **between -1 and 1** with **step 0.1**.
#
# **Goal:** Find the functions by plotting, tuning $α_1, \ldots, α_N$ to figure out the function.
#
# **Note:** In a real experiment, you would not know the coefficients. Here we will generate them in code.

# %% [markdown]
# Fix $N$ - the number of *modes* (a name for different trig functions used to obtain a function) and generate a mystery function.

# %%
Nmyst = 6
Fmyst = create_mystery_function(Nmyst)
display(
    Latex(
        r"$F_{\text{myst}}(x)$ is a function that has the form "
        + r"$\sum_{n=1}^{N} α_n \sin(2\pi n x)$"
        + r" with random numbers $α_n\in [-1,1]$."
    )
)
display(Latex(f"It consists of ${Nmyst}$ Fourier modes."))
# Out:
# $F_{\text{myst}}(x)$ is a function that has the form $\sum_{n=1}^{N} α_n \sin(2\pi n x)$ with random numbers $α_n\in [-1,1]$.
# It consists of $6$ Fourier modes.

# %%
# Display it on a figure.
fig_mystery = Figure(x_range=(-1 / 2, 1 / 2))
fig_mystery.show()

with fig_mystery:
    set_title(r"The mystery function $F_{\text{myst}}(x)$ with "+f"{Nmyst}"+" Fourier modes.")
    plot(Fmyst(x), x, id="F_myst", label=r"$F_{\text{myst}}$")
# Out:
# OneShotOutput()

# %% [markdown]
# ## Build a sine-sum model with adjustable parameters
#
# Now you will build a *model*:
# $$
# \sum_{n=1}^{N} a_n\,\sin(2\pi n x).
# $$
#
# with numbers $a_1,\dots,a_{N}$  *you control*.
#
# **Goal:** Use sliders to tune the numbers $a_1,a_2,\ldots$ so that your model matches the mystery function $F(x)$.

# %% [markdown]
# ### Defining the model
# You can define the expression `model` using the following code
# ```python
# # Model
# model = a[1] * sin(2 * pi * 1 * x) + a[2] * sin(2 * pi * 2 * x) + a[3] * sin(2 * pi * 3 * x)
# display(model)
# ```
# You can directly run the cell with it, below.
#
# After that, we will plot the model with the mystery function.

# %%
# Model
model = a[1] * sin(2 * pi * 1 * x) + a[2] * sin(2 * pi * 2 * x)+ a[3] * sin(2 * pi * 3 * x)
display(model)
# Out:
# a_1*sin(2*pi*x) + a_2*sin(4*pi*x) + a_3*sin(6*pi*x)

# %% [markdown]
# ### Plot mystery vs model (with sliders)
#
# This is the main interactive plot.
#
# - The **mystery** function is fixed.
# - The **model** has sliders for `a[1]`, ..., `a[3]`.
#
# Try to make the two curves overlap as closely as you can.

# %%
fig = Figure(x_range=(-1 / 2, 1 / 2))
fig.show()


with fig:
    set_title(r"Fitting the model to $F(x)$")
    plot(Fmyst(x), x, id="F_{myst}(x)", label=r"$F_{\text{myst}}(x)$")
    plot(model, x, id="model", label=r"$\text{model}(x)$")

# Provide feedback on the difference between Fmyst and model.
fig.info(MaxDistanceCard(x, Fmyst(x), model), id="F_minus_model")
# Out:
# OneShotOutput()

# %% [markdown]
# ### Problem!!
#
# The `model`=$a_1 \sin(2 π x)+a_2 \sin (2 π 2 x)+a_3 \sin(2 π 3 x)$ is clearly **not enough**.
#
# The function $F(x)$ has more sine terms!
#
# **Fix:**
#
# Go back to the code and
# - Remember how many modes $N$ were there in the mystery function
# - Modify the model to have as many sine modes are there in $F(x)$
# - Don't forget to regenerate the plot
# - Try to fit the model.
#
#
# **Goal:**
#
# Find the parameter values such that the difference between the function $F(x)$ and `model` is at most 0.01. When you manage, take a screenshot of your result.

# %% [markdown]
# ## More advanced activities

# %% [markdown]
# ### 1. More modes

# %% [markdown]
# Go back towards the beginning of the notebook and generate a new mystery function with $N=6$. Modify the model to be able to fit it correctly. Take a screenshot once you are close with precision at most $0.01$

# %% [markdown]
# ## What's next?
# Go the notebook `Fourier_02.ipynb` to try to fit other functions

# %% [markdown]
# ## Setup
#
# Run the setup cells. (If your environment already has these packages, the install step may do nothing.)

# %%
# SETUP CELL (optional)
# %pip -q install numpy matplotlib ipywidgets plotly sympy scipy pandas anywidget
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# SETUP CELL 
import src_path
from gu_toolkit import *

# %% [markdown]
# # Activity: Two ways to write the same sinusoid
#
# This activity compares two common ways to write a 1‑periodic sinusoid:
#
# 1. **Linear combination form**
# $$
# f(x)=a\sin(2\pi x)+b\cos(2\pi x).
# $$
#
# 2. **Amplitude–phase form**
# $$
# g(x)=C\sin(2\pi x-\phi).
# $$
#
# Your goal is to experiment numerically and discover how $(a,b)$ corresponds to $(C,\phi)$.

# %% [markdown]
# ## Tune $C$ and $\phi$ to match a chosen $a,b$
#
# 1. Adjust $C$ and $\phi$
# 2. Choose values of $a$ and $b$ so that the two curves overlap:
# $$
# a\sin(2\pi x)+b\cos(2\pi x)\quad\text{and}\quad C\sin(2\pi x-\phi).
# $$
#
# **You do it:**
# Use the code below to create a figure and compare the functions
# ```python
# fig_1 = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-3, 3))
# fig_1.title=r"Trig functions with phase shift: $C\sin(2\pi x -\phi)$"
# display(fig_1)
#
# with fig_1:
#     plot(C*sin(2*pi*x - phi), x, id="sin_phase_shift")
#     plot(a*sin(2*pi*x)+b*cos(2*pi*x), x, id="sin+cos")
# ```

# %% [markdown]
# What is going on? Do you have an idea on how the paratmeres are related?

# %% [markdown]
# ## Investigate “polar coordinates” in the $(a,b)$-plane
#
# Think of the pair $(a,b)$ as a vector in the plane. A natural reparameterization is:
#
# - $r \ge 0$: the **length** of $(a,b)$,
# - $\theta$: the **angle** of $(a,b)$ (up to a sign convention).

# %% [markdown]
# **Question**
# What are the values of $(a,b)$ if the angle is $\theta$ and the length is $r$?

# %% [markdown]
# ## Try plotting when (a,b) are described using "polar coordinates"
#
# Think of the pair $(a,b)$ as a vector in the plane. A natural reparameterization is:
#
# - $r \ge 0$: the **length** of $(a,b)$,
# - $\theta$: the **angle** of $(a,b)$ (up to a sign convention).
#
# **You do it:**
# Modify the code below to make $a$ and $b$ be expressed in terms of $r$ and $\theta$ (use variable names `r` and `theta`)
#
# Remember, in polar coordinates: $a= r \cos(\theta)$ and $b=r\sin(\theta)$
#
# ```python
# fig_2 = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-3, 3))
# fig_2.title=r"Trig functions with phase shift: $C\sin(2\pi x -\phi)$ (polar)"
# display(fig_2)
#
# with fig_2:
#     plot(C*sin(2*pi*x - phi), x, id="sin_phase_shift")
#     plot(a*sin(2*pi*x)+b*cos(2*pi*x), x, id="sin+cos")
#
# ```

# %%
fig_2 = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-3, 3))
fig_2.title=r"Trig functions with phase shift: $C\sin(2\pi x -\phi)$ (polar)"
display(fig_2)

with fig_2:
    plot(C*sin(2*pi*x - phi), x, id="sin_phase_shift")
    plot(a*sin(2*pi*x)+b*cos(2*pi*x), x, id="sin+cos")
# Out:
# C:\Users\guraltsev\AppData\Local\Temp\ipykernel_38284\2412156771.py:1: DeprecationWarning: Figure(x_range=...) is deprecated; use Figure(default_x_range=...) instead.
#   fig_2 = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-3, 3))
# C:\Users\guraltsev\AppData\Local\Temp\ipykernel_38284\2412156771.py:1: DeprecationWarning: Figure(y_range=...) is deprecated; use Figure(default_y_range=...) instead.
#   fig_2 = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-3, 3))
# OneShotOutput()

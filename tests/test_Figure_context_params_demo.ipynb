# %% [markdown]
# # Figure context-managed parameters (manual demo)
#
# Automatable semantics are covered in `tests/test_Figure_module_params.py` and `tests/test_param_hook_context_binding.py`.
# This notebook remains for interactive/context UX demonstration.

# %%
import sys
from pathlib import Path

import sympy as sp

ROOT = Path.cwd().resolve().parents[1]
sys.path.insert(0, str(ROOT / "src"))
from gu_toolkit import Figure, parameters

# %%
x, a = sp.symbols("x a")
fig = Figure(default_x_range=(-6, 6), default_y_range=(-3, 3))
with fig:
    fig.plot(a * sp.sin(x), x, id="a_sin")
    parameters[a].value = 2
fig

# %% [markdown]
# ## Manual checklist
# - [ ] Curve updates when parameter value is changed.
# - [ ] Parameter edits through `parameters[...]` are reflected in the widget.

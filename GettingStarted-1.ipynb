# %%
# %pip -q install ipywidgets sympy numpy pandas  plotly anywidget
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from gu_toolkit import *

# %%
fig.samples
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 fig.samples
#
# AttributeError: 'SmartFigure' object has no attribute 'samples'

# %%
fig=SmartFigure(sample)
# Out:
# HBox(children=(VBox(layout=Layout(display='none', max_width='360px', overflow='auto', padding='0 10px 0 0')), …

# %%
a=Symbol('a')
fig.plot(a-x**2,symbol=x, name="parabola")
# Out:
# <Plot 'parabola': a - x**2 params=[a] | visible=True>

# %%
def make_random_function():
    expr=0
    for n in range(11):
        # Generate random integer j from 0 to 20
        # Calculate coefficient: j/10 - 1
        j = np.random.randint(0, 20)
        a_n = sp.Rational(j, 10) - 1
        
        # Add term to the expression
        expr = expr+ a_n * sin(2 * pi * n * x)
    f_numpy=numpify(expr)
    @NamedFunction
    def F(arg):
        return None
    F.f_numpy=f_numpy
    return F

F=make_random_function()
display(F(x))
display(F(x).rewrite("expand_definition"))
# Out:
# F(x)
# F(x)
# np.float64(3.516884668922563)

# %%
fig.plot(F(x),symbol=x, name="Hidden")
# Out:
# <Plot 'Hidden': F(x) | visible=True>
